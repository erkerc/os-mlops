# %%
import psycopg

# Replace the placeholders with your actual database credentials
DB_NAME = "demodb"
DB_USER = "demodb"
DB_PASSWORD = "demodb"
DB_HOST = "shared-database.shared-database.svc.cluster.local"
DB_PORT = "5432"  # Default is 5432

db_name = os.getenv('DB_NAME', 'claimsdb')
db_user = os.getenv('DB_USER', 'claimsdb)
db_password = os.getenv('DB_PASSWORD', 'claimsdb')
db_host = os.getenv('DB_HOST', 'claimsdb')
db_port = os.getenv('DB_PORT', '5432')

try:
    # Establish the connection
    connection = psycopg.connect(
        dbname=db_name,
        user=db_user,
        password=db_password,
        host=db_host,
        port=db_port
    )

    # Create a cursor object using the connection
    cursor = connection.cursor()

    # Execute a SQL query
    #cursor.execute("SELECT version();")
    
    # Fetch one result
    #db_version = cursor.fetchone()
    #print(f"PostgreSQL database version: {db_version}")

    # Execute a SQL query
    cursor.execute("SELECT * from claims.claims")
    records = cursor.fetchall()
    print(f"Claims table records: {records}")

    
    
    # Close the cursor and connection
    cursor.close()
    connection.close()

except (Exception, psycopg.DatabaseError) as error:
    print(f"Error connecting to PostgreSQL database: {error}")
# Out:
# PostgreSQL database version: ('PostgreSQL 13.14 on x86_64-redhat-linux-gnu, compiled by gcc (GCC) 11.4.1 20230605 (Red Hat 11.4.1-2), 64-bit',)
# ...
